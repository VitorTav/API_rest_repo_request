# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"40305680827","type":"ForkEvent","actor":{"id":42590342,"login":"BennettGrider","display_login":"BennettGrider","gravatar_id":"","url":"https://api.github.com/users/BennettGrider","avatar_url":"https://avatars.githubusercontent.com/u/42590342?"},"repo":{"id":136341685,"name":"Baseflow/flutter-geolocator","url":"https://api.github.com/repos/Baseflow/flutter-geolocator"},"payload":{"forkee":{"id":831141399,"node_id":"R_kgDOMYo2Fw","name":"flutter-geolocator-with-gnss-extras","full_name":"BennettGrider/flutter-geolocator-with-gnss-extras","private":false,"owner":{"login":"BennettGrider","id":42590342,"node_id":"MDQ6VXNlcjQyNTkwMzQy","avatar_url":"https://avatars.githubusercontent.com/u/42590342?v=4","gravatar_id":"","url":"https://api.github.com/users/BennettGrider","html_url":"https://github.com/BennettGrider","followers_url":"https://api.github.com/users/BennettGrider/followers","following_url":"https://api.github.com/users/BennettGrider/following{/other_user}","gists_url":"https://api.github.com/users/BennettGrider/gists{/gist_id}","starred_url":"https://api.github.com/users/BennettGrider/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/BennettGrider/subscriptions","organizations_url":"https://api.github.com/users/BennettGrider/orgs","repos_url":"https://api.github.com/users/BennettGrider/repos","events_url":"https://api.github.com/users/BennettGrider/events{/privacy}","received_events_url":"https://api.github.com/users/BennettGrider/received_events","type":"User","site_admin":false},"html_url":"https://github.com/BennettGrider/flutter-geolocator-with-gnss-extras","description":"Android and iOS Geolocation plugin for Flutter. This fork of flutter-geolocator implements the use of Android location extras, as well as custom iOS implementaiton, to integrate direct connection with GNSS receivers (in particular the EOS Arrow.)","fork":true,"url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras","forks_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/forks","keys_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/keys{/key_id}","collaborators_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/teams","hooks_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/hooks","issue_events_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/issues/events{/number}","events_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/events","assignees_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/assignees{/user}","branches_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/branches{/branch}","tags_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/tags","blobs_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/git/refs{/sha}","trees_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/git/trees{/sha}","statuses_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/statuses/{sha}","languages_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/languages","stargazers_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/stargazers","contributors_url":"https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/contributors","subscribers_url":"https://api.github.com/repos/Benn ...

# %%
r.json()
# Out:
# [{'id': '40305680827',
#   'type': 'ForkEvent',
#   'actor': {'id': 42590342,
#    'login': 'BennettGrider',
#    'display_login': 'BennettGrider',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BennettGrider',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42590342?'},
#   'repo': {'id': 136341685,
#    'name': 'Baseflow/flutter-geolocator',
#    'url': 'https://api.github.com/repos/Baseflow/flutter-geolocator'},
#   'payload': {'forkee': {'id': 831141399,
#     'node_id': 'R_kgDOMYo2Fw',
#     'name': 'flutter-geolocator-with-gnss-extras',
#     'full_name': 'BennettGrider/flutter-geolocator-with-gnss-extras',
#     'private': False,
#     'owner': {'login': 'BennettGrider',
#      'id': 42590342,
#      'node_id': 'MDQ6VXNlcjQyNTkwMzQy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/42590342?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/BennettGrider',
#      'html_url': 'https://github.com/BennettGrider',
#      'followers_url': 'https://api.github.com/users/BennettGrider/followers',
#      'following_url': 'https://api.github.com/users/BennettGrider/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/BennettGrider/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/BennettGrider/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/BennettGrider/subscriptions',
#      'organizations_url': 'https://api.github.com/users/BennettGrider/orgs',
#      'repos_url': 'https://api.github.com/users/BennettGrider/repos',
#      'events_url': 'https://api.github.com/users/BennettGrider/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/BennettGrider/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/BennettGrider/flutter-geolocator-with-gnss-extras',
#     'description': 'Android and iOS Geolocation plugin for Flutter. This fork of flutter-geolocator implements the use of Android location extras, as well as custom iOS implementaiton, to integrate direct connection with GNSS receivers (in particular the EOS Arrow.)',
#     'fork': True,
#     'url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras',
#     'forks_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/forks',
#     'keys_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/teams',
#     'hooks_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/hooks',
#     'issue_events_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/events',
#     'assignees_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/tags',
#     'blobs_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/languages',
#     'stargazers_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/stargazers',
#     'contributors_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/contributors',
#     'subscribers_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/subscribers',
#     'subscription_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/subscription',
#     'commits_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/merges',
#     'archive_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/downloads',
#     'issues_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/BennettGrider/flutter-geolocator-with-gnss-extras/deployments',
#     'created_at': '2024-07-19T18:58:43Z',
#     'updated_at': '2024-07-19T18:58:43Z',
#     'pushed_at': '2024-07-15T03:58:33Z',
#     'git_url': 'git://github.com/BennettGrider/flutter-geolocator-with-gnss-extras.git',
#     'ssh_url': 'git@github.com:BennettGrider/flutter-geolocator-with-gnss-extras.git',
#     'clone_url': 'https://github.com/BennettGrider/flutter-geolocator-with-gnss-extras.git',
#     'svn_url': 'https://github.com/BennettGrider/flutter-geolocator-with-gnss-extras',
#     'homepage': 'https://baseflow.com/',
#     'size': 1954,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2024-07-19T18:58:44Z',
#   'org': {'id': 37274346,
#    'login': 'Baseflow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Baseflow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37274346?'}},
#  {'id': '40305680796',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 104660922,
#    'login': 'aws-aemilia-pdx',
#    'display_login': 'aws-aemilia-pdx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aws-aemilia-pdx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104660922?'},
#   'repo': {'id': 810155444,
#    'name': 'aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#    'url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2'},
#   'payload': {'action': 'opened',
#    'number': 4369,
#    'pull_request': {'url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls/4369',
#     'id': 1978610439,
#     'node_id': 'PR_kwDOMEn9tM517zMH',
#     'html_url': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pull/4369',
#     'diff_url': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pull/4369.diff',
#     'patch_url': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pull/4369.patch',
#     'issue_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues/4369',
#     'number': 4369,
#     'state': 'open',
#     'locked': False,
#     'title': 'Automated test pull request',
#     'user': {'login': 'aws-aemilia-pdx',
#      'id': 104660922,
#      'node_id': 'U_kgDOBjz_ug',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/104660922?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/aws-aemilia-pdx',
#      'html_url': 'https://github.com/aws-aemilia-pdx',
#      'followers_url': 'https://api.github.com/users/aws-aemilia-pdx/followers',
#      'following_url': 'https://api.github.com/users/aws-aemilia-pdx/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/aws-aemilia-pdx/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/aws-aemilia-pdx/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/aws-aemilia-pdx/subscriptions',
#      'organizations_url': 'https://api.github.com/users/aws-aemilia-pdx/orgs',
#      'repos_url': 'https://api.github.com/users/aws-aemilia-pdx/repos',
#      'events_url': 'https://api.github.com/users/aws-aemilia-pdx/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/aws-aemilia-pdx/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Automated test pull request',
#     'created_at': '2024-07-19T18:58:42Z',
#     'updated_at': '2024-07-19T18:58:42Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'ce23b4cdfccb40e9daa028d6e3f60c0340586292',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls/4369/commits',
#     'review_comments_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls/4369/comments',
#     'review_comment_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues/4369/comments',
#     'statuses_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/statuses/ab19f0418471996fed957f0ff2fcaca1fa9c721c',
#     'head': {'label': 'aws-aemilia-pdx:GitHubAutoBuildPrPreviewCanaryTestpr-preprod-1721415521310',
#      'ref': 'GitHubAutoBuildPrPreviewCanaryTestpr-preprod-1721415521310',
#      'sha': 'ab19f0418471996fed957f0ff2fcaca1fa9c721c',
#      'user': {'login': 'aws-aemilia-pdx',
#       'id': 104660922,
#       'node_id': 'U_kgDOBjz_ug',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/104660922?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/aws-aemilia-pdx',
#       'html_url': 'https://github.com/aws-aemilia-pdx',
#       'followers_url': 'https://api.github.com/users/aws-aemilia-pdx/followers',
#       'following_url': 'https://api.github.com/users/aws-aemilia-pdx/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/aws-aemilia-pdx/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/aws-aemilia-pdx/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/aws-aemilia-pdx/subscriptions',
#       'organizations_url': 'https://api.github.com/users/aws-aemilia-pdx/orgs',
#       'repos_url': 'https://api.github.com/users/aws-aemilia-pdx/repos',
#       'events_url': 'https://api.github.com/users/aws-aemilia-pdx/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/aws-aemilia-pdx/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 810155444,
#       'node_id': 'R_kgDOMEn9tA',
#       'name': 'Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'full_name': 'aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'private': False,
#       'owner': {'login': 'aws-aemilia-pdx',
#        'id': 104660922,
#        'node_id': 'U_kgDOBjz_ug',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/104660922?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/aws-aemilia-pdx',
#        'html_url': 'https://github.com/aws-aemilia-pdx',
#        'followers_url': 'https://api.github.com/users/aws-aemilia-pdx/followers',
#        'following_url': 'https://api.github.com/users/aws-aemilia-pdx/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/aws-aemilia-pdx/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/aws-aemilia-pdx/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/aws-aemilia-pdx/subscriptions',
#        'organizations_url': 'https://api.github.com/users/aws-aemilia-pdx/orgs',
#        'repos_url': 'https://api.github.com/users/aws-aemilia-pdx/repos',
#        'events_url': 'https://api.github.com/users/aws-aemilia-pdx/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/aws-aemilia-pdx/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'forks_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/forks',
#       'keys_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/teams',
#       'hooks_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/hooks',
#       'issue_events_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/events',
#       'assignees_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/tags',
#       'blobs_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/languages',
#       'stargazers_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/stargazers',
#       'contributors_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/contributors',
#       'subscribers_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/subscribers',
#       'subscription_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/subscription',
#       'commits_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/merges',
#       'archive_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/downloads',
#       'issues_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/deployments',
#       'created_at': '2024-06-04T06:43:46Z',
#       'updated_at': '2024-06-04T06:43:51Z',
#       'pushed_at': '2024-07-19T18:58:43Z',
#       'git_url': 'git://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2.git',
#       'ssh_url': 'git@github.com:aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2.git',
#       'clone_url': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2.git',
#       'svn_url': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'homepage': None,
#       'size': 2,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'aws-aemilia-pdx:main',
#      'ref': 'main',
#      'sha': '4e43a56e53afc7873bbc94f32d6d57dbb0dd3bd5',
#      'user': {'login': 'aws-aemilia-pdx',
#       'id': 104660922,
#       'node_id': 'U_kgDOBjz_ug',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/104660922?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/aws-aemilia-pdx',
#       'html_url': 'https://github.com/aws-aemilia-pdx',
#       'followers_url': 'https://api.github.com/users/aws-aemilia-pdx/followers',
#       'following_url': 'https://api.github.com/users/aws-aemilia-pdx/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/aws-aemilia-pdx/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/aws-aemilia-pdx/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/aws-aemilia-pdx/subscriptions',
#       'organizations_url': 'https://api.github.com/users/aws-aemilia-pdx/orgs',
#       'repos_url': 'https://api.github.com/users/aws-aemilia-pdx/repos',
#       'events_url': 'https://api.github.com/users/aws-aemilia-pdx/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/aws-aemilia-pdx/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 810155444,
#       'node_id': 'R_kgDOMEn9tA',
#       'name': 'Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'full_name': 'aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'private': False,
#       'owner': {'login': 'aws-aemilia-pdx',
#        'id': 104660922,
#        'node_id': 'U_kgDOBjz_ug',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/104660922?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/aws-aemilia-pdx',
#        'html_url': 'https://github.com/aws-aemilia-pdx',
#        'followers_url': 'https://api.github.com/users/aws-aemilia-pdx/followers',
#        'following_url': 'https://api.github.com/users/aws-aemilia-pdx/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/aws-aemilia-pdx/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/aws-aemilia-pdx/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/aws-aemilia-pdx/subscriptions',
#        'organizations_url': 'https://api.github.com/users/aws-aemilia-pdx/orgs',
#        'repos_url': 'https://api.github.com/users/aws-aemilia-pdx/repos',
#        'events_url': 'https://api.github.com/users/aws-aemilia-pdx/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/aws-aemilia-pdx/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'forks_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/forks',
#       'keys_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/teams',
#       'hooks_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/hooks',
#       'issue_events_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/events',
#       'assignees_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/tags',
#       'blobs_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/languages',
#       'stargazers_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/stargazers',
#       'contributors_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/contributors',
#       'subscribers_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/subscribers',
#       'subscription_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/subscription',
#       'commits_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/merges',
#       'archive_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/downloads',
#       'issues_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/deployments',
#       'created_at': '2024-06-04T06:43:46Z',
#       'updated_at': '2024-06-04T06:43:51Z',
#       'pushed_at': '2024-07-19T18:58:43Z',
#       'git_url': 'git://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2.git',
#       'ssh_url': 'git@github.com:aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2.git',
#       'clone_url': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2.git',
#       'svn_url': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2',
#       'homepage': None,
#       'size': 2,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls/4369'},
#      'html': {'href': 'https://github.com/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pull/4369'},
#      'issue': {'href': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues/4369'},
#      'comments': {'href': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/issues/4369/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls/4369/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/pulls/4369/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2/statuses/ab19f0418471996fed957f0ff2fcaca1fa9c721c'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2024-07-19T18:58:44Z'},
#  {'id': '40305680765',
#   'type': 'PushEvent',
#   'actor': {'id': 166895733,
#    'login': 'swa-runner-app[bot]',
#    'display_login': 'swa-runner-app',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swa-runner-app[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166895733?'},
#   'repo': {'id': 831141317,
#    'name': 'static-web-apps-testing-org/swa84f37d05b5ef40839aa7fc0e3bd92af8',
#    'url': 'https://api.github.com/repos/static-web-apps-testing-org/swa84f37d05b5ef40839aa7fc0e3bd92af8'},
#   'payload': {'repository_id': 831141317,
#    'push_id': 19397895450,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd0c7470db6d7369284b2ca25c67bd345cece9ace',
#    'before': '5d5013defe464428119f60bde599a586391c078b',
#    'commits': [{'sha': 'd0c7470db6d7369284b2ca25c67bd345cece9ace',
#      'author': {'email': '166895733+swa-runner-app[bot]@users.noreply.github.com',
#       'name': 'swa-runner-app[bot]'},
#      'message': 'Writing file Client/Layout/NavMenu.razor.css',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/static-web-apps-testing-org/swa84f37d05b5ef40839aa7fc0e3bd92af8/commits/d0c7470db6d7369284b2ca25c67bd345cece9ace'}]},
#   'public': True,
#   'created_at': '2024-07-19T18:58:44Z',
#   'org': {'id': 96167003,
#    'login': 'static-web-apps-testing-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/static-web-apps-testing-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96167003?'}},
#  {'id': '40305680792',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 4380887,
#    'login': 'ee-forge',
#    'display_login': 'ee-forge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ee-forge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4380887?'},
#   'repo': {'id': 157293216,
#    'name': 'ExpressionEngine/ExpressionEngine',
#    'url': 'https://api.github.com/repos/ExpressionEngine/ExpressionEngine'},
#   'payload': {'action': 'opened',
#    'number': 4401,
#    'pull_request': {'url': 'https://api.github.com/repos/ExpressionEngine/ExpressionEngine/pulls/4401',
#     'id': 1978610456,
#     'node_id': 'PR_kwDOCWAaoM517zMY',
#     'html_url': 'https://github.com/ExpressionEngine/ExpressionEngine/pull/4401',
#     'diff_url': 'https://github.com/ExpressionEngine/ExpressionEngine/pull/4401.diff',
#     'patch_url': 'https://github.com/ExpressionEngine/ExpressionEngine/pull/4401.patch',
#     'issue_url': 'https://api.github.com/repos/ExpressionEngine/ExpressionEngine/issues/4401',
#     'number': 4401,
#     'state': 'open',
#     'locked': False,
#     'title': 'Resolved #4400 where addon control panel routes did not allow multiple segments',
#     'user': {'login': 'ee-forge',
#      'id': 4380887,
#      'node_id': 'MDQ6VXNlcjQzODA4ODc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/4380887?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ee-forge',
#      'html_url': 'https://github.com/ee-forge',
#      'followers_url': 'https://api.github.com/users/ee-forge/followers',
#      'following_url': 'https://api.github.com/users/ee-forge/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ee-forge/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ee-forge/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ee-forge/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ee-forge/orgs',
#      'repos_url': 'https://api.github.com/users/ee-forge/repos',
#      'events_url': 'https://api.github.com/users/ee-forge/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ee-forge/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Changes the `buildObject` method to assume the new Control Panel/Routes and fallback to the legacy Mcp/ folder.  This is the inversion of the original approach.\r\n',
#     'created_at': '2024-07-19T18:58:43Z',
#     'updated_at': '2024-07-19T18:58:43Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/ExpressionEngine/ExpressionEngine/pulls/4401/commits',
#     'review_comments_url': 'https://api.github.com/repos/ExpressionEngine/ExpressionEngine/pulls/4401/comments',
#     'review_comment_url': 'https://api.github.com/repos/ExpressionEngine/ExpressionEngine/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ExpressionEngine/ExpressionEngine/issues/4401/comments',
#     'statuses_url': 'https://api.github.com/repos/ExpressionEngine/ExpressionEngine/statuses/4a0f6cb52638ab4fe53b04f3670b77f675ab4427',
#     'head': {'label': 'ee-forge:bug/7.x/fix-addon-cp-route-actions',
#      'ref': 'bug/7.x/fix-addon-cp-route-actions',
#      'sha': '4a0f6cb52638ab4fe53b04f3670b77f675ab4427',
#      'user': {'login': 'ee-forge',
#       'id': 4380887,
#       'node_id': 'MDQ6VXNlcjQzODA4ODc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/4380887?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ee-forge',
#       'html_url': 'https://github.com/ee-forge',
#       'followers_url': 'https://api.github.com/users/ee-forge/followers',
#       'following_url': 'https://api.github.com/users/ee-forge/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ee-forge/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ee-forge/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ee-forge/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ee-forge/orgs',
#       'repos_url': 'https://api.github.com/users/ee-forge/repos',
#       'events_url': 'https://api.github.com/users/ee-forge/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ee-forge/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 831136375,
#       'node_id': 'R_kgDOMYoidw',
#       'name': 'ExpressionEngine',
#       'full_name': 'ee-forge/ExpressionEngine',
#       'private': False,
#       'owner': {'login': 'ee-forge',
#        'id': 4380887,
#        'node_id': 'MDQ6VXNlcjQzODA4ODc=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/4380887?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ee-forge',
#        'html_url': 'https://github.com/ee-forge',
#        'followers_url': 'https://api.github.com/users/ee-forge/followers',
#        'following_url': 'https://api.github.com/users/ee-forge/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ee-forge/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ee-forge/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ee-forge/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ee-forge/orgs',
#        'repos_url': 'https://api.github.com/users/ee-forge/repos',
#        'events_url': 'https://api.github.com/users/ee-forge/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ee-forge/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ee-forge/ExpressionEngine',
#       'description': 'ExpressionEngine is a flexible, feature-rich, free open-source content management platform that empowers hundreds of thousands of individuals and organizations around the world to easily manage their web site.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/ee-forge/ExpressionEngine',
#       'forks_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/forks',
#       'keys_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/teams',
#       'hooks_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/events',
#       'assignees_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/tags',
#       'blobs_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/languages',
#       'stargazers_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/subscription',
#       'commits_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/merges',
#       'archive_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/downloads',
#       'issues_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ee-forge/ExpressionEngine/deployments',
#       'created_at': '2024-07-19T18:41:38Z',
#       'updated_at': '2024-07-19T18:41:38Z',
#       'pushed_at': '2024-07-19T18:42:21Z',
#       'git_url': 'git://github.com/ee-forge/ExpressionEngine.git',
#       'ssh_url': 'git@github.com:ee-forge/ExpressionEngine.git',
#       'clone_url': 'https://github.com/ee-forge/ExpressionEngine.git',
#       'svn_url': 'https://github.com/ee-forge/ExpressionEngine',
#       'homepage': 'https://expressionengine.com',
#       'size': 361246,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': '7.dev'}},
#     'base': {'label': 'ExpressionEngine:7.dev',
#      'ref': '7.dev',
#      'sha': '335e352d874144a55dda2c1546c17a08c09548c2',
#      'user': {'login': 'ExpressionEngine',
#       'id': 17136433,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3MTM2NDMz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/17136433?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ExpressionEngine',
#       'html_url': 'https://github.com/ExpressionEngine',
#       'followers_url': 'https://api.github.com/users/ExpressionEngine/followers',
#       'following_url': 'https://api.github.com/users/ExpressionEngine/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ExpressionEngine/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ExpressionEngine/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ExpressionEngine/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ExpressionEngine/orgs',
#       'repos_url': 'https://api.github.com/users/ExpressionEngine/repos',
#       'events_url': 'https://api.github.com/users/ExpressionEngine/events{/privacy}',
# ...
#       'releases_url': 'https://api.github.com/repos/ShanbhagChandan/Portfolio/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ShanbhagChandan/Portfolio/deployments',
#       'created_at': '2024-07-18T15:04:06Z',
#       'updated_at': '2024-07-19T10:14:49Z',
#       'pushed_at': '2024-07-19T18:58:43Z',
#       'git_url': 'git://github.com/ShanbhagChandan/Portfolio.git',
#       'ssh_url': 'git@github.com:ShanbhagChandan/Portfolio.git',
#       'clone_url': 'https://github.com/ShanbhagChandan/Portfolio.git',
#       'svn_url': 'https://github.com/ShanbhagChandan/Portfolio',
#       'homepage': None,
#       'size': 685,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ShanbhagChandan/Portfolio/pulls/3'},
#      'html': {'href': 'https://github.com/ShanbhagChandan/Portfolio/pull/3'},
#      'issue': {'href': 'https://api.github.com/repos/ShanbhagChandan/Portfolio/issues/3'},
#      'comments': {'href': 'https://api.github.com/repos/ShanbhagChandan/Portfolio/issues/3/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ShanbhagChandan/Portfolio/pulls/3/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ShanbhagChandan/Portfolio/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ShanbhagChandan/Portfolio/pulls/3/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ShanbhagChandan/Portfolio/statuses/fc1cd867b5dd27ac7693d13d4e4a809af1058235'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 320,
#     'deletions': 109,
#     'changed_files': 18}},
#   'public': True,
#   'created_at': '2024-07-19T18:58:43Z'},
#  {'id': '40305680601',
#   'type': 'PushEvent',
#   'actor': {'id': 60781455,
#    'login': 'FrancisCarolina',
#    'display_login': 'FrancisCarolina',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FrancisCarolina',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60781455?'},
#   'repo': {'id': 831136858,
#    'name': 'FrancisCarolina/desafio-votacao-fullstack',
#    'url': 'https://api.github.com/repos/FrancisCarolina/desafio-votacao-fullstack'},
#   'payload': {'repository_id': 831136858,
#    'push_id': 19397895365,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2167766dd1aafdd62f57a105ca666d8fd41d2ca5',
#    'before': '9417cee6a5f295fd76918774381d14d5b408eea8',
#    'commits': [{'sha': '2167766dd1aafdd62f57a105ca666d8fd41d2ca5',
#      'author': {'email': 'francis.carolinalovo@gmail.com',
#       'name': 'Francis Lovo'},
#      'message': 'inicial front',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/FrancisCarolina/desafio-votacao-fullstack/commits/2167766dd1aafdd62f57a105ca666d8fd41d2ca5'}]},
#   'public': True,
#   'created_at': '2024-07-19T18:58:43Z'},
#  {'id': '40305680569',
#   'type': 'PushEvent',
#   'actor': {'id': 60674096,
#    'login': 'mr-cal',
#    'display_login': 'mr-cal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mr-cal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60674096?'},
#   'repo': {'id': 45199136,
#    'name': 'canonical/snapcraft',
#    'url': 'https://api.github.com/repos/canonical/snapcraft'},
#   'payload': {'repository_id': 45199136,
#    'push_id': 19397895351,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/work/CRAFT-3117/validation-set-tests',
#    'head': '3c557b4dd87dd722f0ac2a4b9b88e8f6a1b9c69b',
#    'before': 'ba92f96b1a1a4596ad3391661d7f23aa9e77ee87',
#    'commits': [{'sha': '3c557b4dd87dd722f0ac2a4b9b88e8f6a1b9c69b',
#      'author': {'email': 'callahan.kovacs@canonical.com',
#       'name': 'Callahan Kovacs'},
#      'message': 'tests: add spread tests for validation-sets\n\nSigned-off-by: Callahan Kovacs <callahan.kovacs@canonical.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/canonical/snapcraft/commits/3c557b4dd87dd722f0ac2a4b9b88e8f6a1b9c69b'}]},
#   'public': True,
#   'created_at': '2024-07-19T18:58:43Z',
#   'org': {'id': 53057619,
#    'login': 'canonical',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/canonical',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53057619?'}},
#  {'id': '40305680584',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 10799815,
#    'login': 'DerekCaelin',
#    'display_login': 'DerekCaelin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DerekCaelin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10799815?'},
#   'repo': {'id': 611416560,
#    'name': 'techmatters/terraso-mobile-client',
#    'url': 'https://api.github.com/repos/techmatters/terraso-mobile-client'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/issues/1780',
#     'repository_url': 'https://api.github.com/repos/techmatters/terraso-mobile-client',
#     'labels_url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/issues/1780/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/issues/1780/comments',
#     'events_url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/issues/1780/events',
#     'html_url': 'https://github.com/techmatters/terraso-mobile-client/issues/1780',
#     'id': 2411897818,
#     'node_id': 'I_kwDOJHF58M6PwqPa',
#     'number': 1780,
#     'title': "on Android, user can't see own location on first load of map",
#     'user': {'login': 'DerekCaelin',
#      'id': 10799815,
#      'node_id': 'MDQ6VXNlcjEwNzk5ODE1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/10799815?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DerekCaelin',
#      'html_url': 'https://github.com/DerekCaelin',
#      'followers_url': 'https://api.github.com/users/DerekCaelin/followers',
#      'following_url': 'https://api.github.com/users/DerekCaelin/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DerekCaelin/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DerekCaelin/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DerekCaelin/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DerekCaelin/orgs',
#      'repos_url': 'https://api.github.com/users/DerekCaelin/repos',
#      'events_url': 'https://api.github.com/users/DerekCaelin/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DerekCaelin/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 5242387468,
#       'node_id': 'LA_kwDOJHF58M8AAAABOHh8DA',
#       'url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/labels/bug',
#       'name': 'bug',
#       'color': 'd73a4a',
#       'default': True,
#       'description': "Something isn't working"},
#      {'id': 6811256725,
#       'node_id': 'LA_kwDOJHF58M8AAAABlfuHlQ',
#       'url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/labels/Engineering',
#       'name': 'Engineering',
#       'color': '0e8a16',
#       'default': False,
#       'description': ''},
#      {'id': 7131811973,
#       'node_id': 'LA_kwDOJHF58M8AAAABqRbQhQ',
#       'url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/labels/needs%20triage',
#       'name': 'needs triage',
#       'color': 'FFAA04',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/milestones/10',
#      'html_url': 'https://github.com/techmatters/terraso-mobile-client/milestone/10',
#      'labels_url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/milestones/10/labels',
#      'id': 10115431,
#      'node_id': 'MI_kwDOJHF58M4Amlln',
#      'number': 10,
#      'title': 'LandPKS Backlog',
#      'description': None,
#      'creator': {'login': 'ltseng',
#       'id': 2730009,
#       'node_id': 'MDQ6VXNlcjI3MzAwMDk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2730009?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ltseng',
#       'html_url': 'https://github.com/ltseng',
#       'followers_url': 'https://api.github.com/users/ltseng/followers',
#       'following_url': 'https://api.github.com/users/ltseng/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ltseng/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ltseng/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ltseng/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ltseng/orgs',
#       'repos_url': 'https://api.github.com/users/ltseng/repos',
#       'events_url': 'https://api.github.com/users/ltseng/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ltseng/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 104,
#      'closed_issues': 62,
#      'state': 'open',
#      'created_at': '2023-10-27T17:17:02Z',
#      'updated_at': '2024-07-19T17:54:56Z',
#      'due_on': None,
#      'closed_at': None},
#     'comments': 1,
#     'created_at': '2024-07-16T19:28:13Z',
#     'updated_at': '2024-07-19T18:58:43Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': '### App Version\r\n\r\n169\r\n\r\n### Account\r\n\r\n_No response_\r\n\r\n### Platforms\r\n\r\n- [ ] iOS\r\n- [X] Android\r\n- [ ] iOS simulator\r\n- [ ] Android emulator\r\n\r\n### Description\r\n\r\nFirst-time Android users can\'t see their own position on the map, and the "my location" button fails silently. Reloading the app once permissions have been granted allows the map to see the user\'s location. \r\n\r\n### Steps to Reproduce\r\n\r\nOn Android:\r\n1. Uninstall, reinstall and open app\r\n2. Pass through interstitial\r\n3. Sign in with any identity\r\n4. Open home screen and accept permissions request\r\n5. See issue\r\n6. Tap "my location" button\r\n7. See issue\r\n\r\n### Expected behavior\r\n\r\nThe map will know and center on the user\'s location\r\nTapping on "My location" button will center the map on the user\'s location\r\n\r\n### Actual behavior\r\n\r\nThe user provides permission, but no point representing the user appears on the map, and the "my location" button does nothing. \r\n\r\n### Additional context\r\n\r\n- Upon closing and re-opening the app, the map can pull the user\'s own location\r\n- on iOS, permissions are granted on the intersitial screen, but on android, Permissions come when viewing the map. Theory: the app tries and fails to get the user\'s location, asks for permission, but doesn\'t try again to get location once it has permission. ',
#     'reactions': {'url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/issues/1780/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/issues/1780/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/issues/comments/2239926666',
#     'html_url': 'https://github.com/techmatters/terraso-mobile-client/issues/1780#issuecomment-2239926666',
#     'issue_url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/issues/1780',
#     'id': 2239926666,
#     'node_id': 'IC_kwDOJHF58M6FgpGK',
#     'user': {'login': 'DerekCaelin',
#      'id': 10799815,
#      'node_id': 'MDQ6VXNlcjEwNzk5ODE1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/10799815?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DerekCaelin',
#      'html_url': 'https://github.com/DerekCaelin',
#      'followers_url': 'https://api.github.com/users/DerekCaelin/followers',
#      'following_url': 'https://api.github.com/users/DerekCaelin/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DerekCaelin/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DerekCaelin/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DerekCaelin/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DerekCaelin/orgs',
#      'repos_url': 'https://api.github.com/users/DerekCaelin/repos',
#      'events_url': 'https://api.github.com/users/DerekCaelin/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DerekCaelin/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2024-07-19T18:58:42Z',
#     'updated_at': '2024-07-19T18:58:42Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Possibly related to https://github.com/techmatters/terraso-mobile-client/issues/1749',
#     'reactions': {'url': 'https://api.github.com/repos/techmatters/terraso-mobile-client/issues/comments/2239926666/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-07-19T18:58:43Z',
#   'org': {'id': 53062258,
#    'login': 'techmatters',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/techmatters',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53062258?'}},
#  {'id': '40305680585',
#   'type': 'PushEvent',
#   'actor': {'id': 11057080,
#    'login': 'pejotes',
#    'display_login': 'pejotes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pejotes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11057080?'},
#   'repo': {'id': 335982798,
#    'name': 'pejotes/upptime',
#    'url': 'https://api.github.com/repos/pejotes/upptime'},
#   'payload': {'repository_id': 335982798,
#    'push_id': 19397895369,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dceb65ddd5f01ba40eb1c3b03adf1c7024eb78cd',
#    'before': 'f372a1ef67b69984e61f183255ba1ddf49f1bfa8',
#    'commits': [{'sha': 'dceb65ddd5f01ba40eb1c3b03adf1c7024eb78cd',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟩 Beyond.pl is up (200 in 2578 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pejotes/upptime/commits/dceb65ddd5f01ba40eb1c3b03adf1c7024eb78cd'}]},
#   'public': True,
#   'created_at': '2024-07-19T18:58:43Z'},
#  {'id': '40305680576',
#   'type': 'CreateEvent',
#   'actor': {'id': 61440596,
#    'login': 'gabrielgarcia2211',
#    'display_login': 'gabrielgarcia2211',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gabrielgarcia2211',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61440596?'},
#   'repo': {'id': 831141396,
#    'name': 'gabrielgarcia2211/app-inventario',
#    'url': 'https://api.github.com/repos/gabrielgarcia2211/app-inventario'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-07-19T18:58:43Z'}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2024-01-28T17:12:00Z',
#   'pushed_at': '2024-03-14T15:40:19Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 26,
#   'stargazers_count': 12,
#   'watchers_count': 12,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 340,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 340,
#   'open_issues': 3,
#   'watchers': 12,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2024-07-18T14:40:57Z',
#   'pushed_at': '2024-07-18T14:40:53Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 370,
#   'stargazers_count': 84,
#   'watchers_count': 84,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 32,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 20,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 32,
#   'open_issues': 20,
#   'watchers': 84,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2024-07-18T20:03:56Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 24,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 24,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2024-07-01T22:07:12Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1134,
#   'watchers_count': 1134,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1045,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1045,
#   'open_issues': 11,
#   'watchers': 1134,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2024-05-30T21:19:04Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 9,
#   'watchers_count': 9,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 9,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-05-02T06:10:48Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 67,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 67,
#   'open_issues': 14,
#   'watchers': 93,
#   'default_branch': 'master'},
#  {'id': 429297502,
#   'node_id': 'R_kgDOGZaPXg',
#   'name': 'amazon-codeguru-profiler-for-spark',
#   'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'description': 'A Spark plugin for CPU and memory profiling',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#   'created_at': '2021-11-18T04:37:55Z',
#   'updated_at': '2024-06-22T23:16:45Z',
#   'pushed_at': '2024-05-30T18:52:25Z',
#   'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#   'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'homepage': '',
#   'size': 2352,
#   'stargazers_count': 17,
#   'watchers_count': 17,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 11,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 11,
#   'open_issues': 1,
#   'watchers': 17,
#   'default_branch': 'main'},
#  {'id': 397426400,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTc0MjY0MDA=',
#   'name': 'amazon-frustration-free-setup-certification-tool',
# ...
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/deployments',
#   'created_at': '2014-12-05T18:51:43Z',
#   'updated_at': '2024-07-13T00:52:34Z',
#   'pushed_at': '2024-05-30T18:47:19Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-java.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-java.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-java.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 13957,
#   'stargazers_count': 57,
#   'watchers_count': 57,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 51,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 15,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 51,
#   'open_issues': 15,
#   'watchers': 57,
#   'default_branch': 'master'},
#  {'id': 26331269,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMzMTI2OQ==',
#   'name': 'amazon-pay-sdk-php',
#   'full_name': 'amzn/amazon-pay-sdk-php',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'description': 'Amazon Pay PHP SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/deployments',
#   'created_at': '2014-11-07T18:00:47Z',
#   'updated_at': '2024-07-13T00:52:34Z',
#   'pushed_at': '2024-05-14T13:04:33Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-php.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-php.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-php.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 877,
#   'stargazers_count': 207,
#   'watchers_count': 207,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 93,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 37,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 93,
#   'open_issues': 37,
#   'watchers': 207,
#   'default_branch': 'master'},
#  {'id': 29757348,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTc1NzM0OA==',
#   'name': 'amazon-pay-sdk-python',
#   'full_name': 'amzn/amazon-pay-sdk-python',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-python',
#   'description': 'Amazon Pay Python SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/deployments',
#   'created_at': '2015-01-23T23:00:34Z',
#   'updated_at': '2024-07-13T00:52:34Z',
#   'pushed_at': '2024-05-30T18:46:10Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-python.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-python.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-python.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-python',
#   'homepage': '',
#   'size': 85,
#   'stargazers_count': 55,
#   'watchers_count': 55,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 39,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 9,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 39,
#   'open_issues': 9,
#   'watchers': 55,
#   'default_branch': 'master'}]

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como 'limite de taxa'. Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %%
access_token = 'seu_token'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# ### Paginando os repositórios

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [{'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'},
#  {'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'},
#  {'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'},
#  {'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'},
#  {'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'}]

# %%
len(repos_list)
# Out:
# 5

# %%
len(repos_list[0])
# Out:
# 3

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %%
repos_list
# Out:
# [{'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'},
#  {'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'},
#  {'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'},
#  {'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'},
#  {'message': 'Bad credentials',
#   'documentation_url': 'https://docs.github.com/rest',
#   'status': '401'}]

# %%
repos_list[0][2]['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 repos_list[0][2]['name']
#
# KeyError: 2

# %%
repos_name = []
for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs',
#  'amazon-hub-counter-api-samples']

# %%
len(repos_name)
# Out:
# 133

# %% [markdown]
# ### Linguagens dos repositórios

# %%
repos_list[1][1]['language']
# Out:
# 'PHP'

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
len(repos_language)
# Out:
# 133

# %%
repos_language
# Out:
# [None,
#  None,
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  'Kotlin',
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Java',
#  'Java',
#  'Java',
#  'C#',
#  'C#',
#  'JavaScript',
#  'JavaScript',
#  'Go',
#  'Java',
#  'TypeScript',
#  'Python',
#  'C++',
#  None,
#  'Python',
#  'C#',
#  'HTML',
#  None,
#  'PHP',
#  'PHP',
#  'Java',
#  'Python',
#  'Scala',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Swift',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Ruby',
#  'Python',
#  'Python',
#  'C',
#  'Python',
#  'Python',
#  'Python',
#  'C++',
#  'Java',
#  'HTML',
#  'Java',
#  'Python',
#  'Swift',
#  'JavaScript',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Python',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'Python',
#  'JavaScript',
#  'Python',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Zeek',
#  'Python']

# %% [markdown]
# ### Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_name
dados_amz['language'] = repos_language

# %%
dados_amz
# Out:
#                                        repository_name    language
# 0                                              .github        None
# 1                              ads-advanced-tools-docs        None
# 2                                           alexa-coho  JavaScript
# 3                                  alexa-skills-kit-js        None
# 4    amazon-ads-advertiser-audience-normalization-s...      Python
# ..                                                 ...         ...
# 128                                   zeek-plugin-enip        Zeek
# 129                               zeek-plugin-profinet        Zeek
# 130                                 zeek-plugin-s7comm        Zeek
# 131                                    zeek-plugin-tds        Zeek
# 132                                     zero-shot-rlhr      Python
#
# [133 rows x 2 columns]

# %% [markdown]
# Salvando o DataFrame

# %%
dados_amz.to_csv('amazon.csv')

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando repositório com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de prog da Amazon',
    'private': False
}

response = requests.post(url, json=data, headers=headers)
response.status_code
# Out:
# 201

# %% [markdown]
# ### Formato do arquivo

# %%
import base64

# %%
with open('amazon.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)

# %% [markdown]
# ### Upload de arquivo com PUT

# %%
api_base_url = 'https://api.github.com'
username = 'millenagena'
repo = 'linguagens-utilizadas'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/millenagena/linguagens-utilizadas/contents/amazon.csv'

# %%
data = {
    'message': 'Adicionando um novo arquivo',
    'content': encoded_content.decode('utf-8')
}

response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 201
